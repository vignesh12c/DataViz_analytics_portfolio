# %%
# !gdown '14c0zsrBnswZQBTBpWBFyJAFZlZT8aizi'
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=14c0zsrBnswZQBTBpWBFyJAFZlZT8aizi
# To: /content/yulu_CaseStudy.csv
# 100% 659k/659k [00:00<00:00, 9.38MB/s]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df2 =  pd.read_csv('yulu_CaseStudy.csv')
df2
# Out:
#                   datetime  season  holiday  workingday  weather   temp  \
# 0      2011-01-01 00:00:00       1        0           0        1   9.84
# 1      2011-01-01 01:00:00       1        0           0        1   9.02
# 2      2011-01-01 02:00:00       1        0           0        1   9.02
# 3      2011-01-01 03:00:00       1        0           0        1   9.84
# 4      2011-01-01 04:00:00       1        0           0        1   9.84
# ...                    ...     ...      ...         ...      ...    ...
# 10881  2012-12-19 19:00:00       4        0           1        1  15.58
# 10882  2012-12-19 20:00:00       4        0           1        1  14.76
# 10883  2012-12-19 21:00:00       4        0           1        1  13.94
# 10884  2012-12-19 22:00:00       4        0           1        1  13.94
# 10885  2012-12-19 23:00:00       4        0           1        1  13.12
#
#         atemp  humidity  windspeed  casual  registered  count
# ...

# %%
df = df2.copy()

# %%
df.describe()
# Out:
#              season       holiday    workingday       weather         temp  \
# count  10886.000000  10886.000000  10886.000000  10886.000000  10886.00000
# mean       2.506614      0.028569      0.680875      1.418427     20.23086
# std        1.116174      0.166599      0.466159      0.633839      7.79159
# min        1.000000      0.000000      0.000000      1.000000      0.82000
# 25%        2.000000      0.000000      0.000000      1.000000     13.94000
# 50%        3.000000      0.000000      1.000000      1.000000     20.50000
# 75%        4.000000      0.000000      1.000000      2.000000     26.24000
# max        4.000000      1.000000      1.000000      4.000000     41.00000
#
#               atemp      humidity     windspeed        casual    registered  \
# count  10886.000000  10886.000000  10886.000000  10886.000000  10886.000000
# mean      23.655084     61.886460     12.799395     36.021955    155.552177
# ...

# %%
df.isna().sum()
# Out:
# datetime      0
# season        0
# holiday       0
# workingday    0
# weather       0
# temp          0
# atemp         0
# humidity      0
# windspeed     0
# casual        0
# registered    0
# count         0
# dtype: int64

# %% [markdown]
# no null values in data. it is clean

# %%
df.dtypes
# Out:
# datetime       object
# season          int64
# holiday         int64
# workingday      int64
# weather         int64
# temp          float64
# atemp         float64
# humidity        int64
# windspeed     float64
# casual          int64
# registered      int64
# count           int64
# dtype: object

# %%
df = df.astype({'season':'object','holiday':'object','workingday':'object','weather':'object'})

# %%
df.dtypes
# Out:
# datetime       object
# season         object
# holiday        object
# workingday     object
# weather        object
# temp          float64
# atemp         float64
# humidity        int64
# windspeed     float64
# casual          int64
# registered      int64
# count           int64
# dtype: object

# %%
#plt.figure(figsize= (30,16))
df.plot(kind='density',subplots=True,layout=(3,4),sharex=False,figsize=(30,16))
plt.show()

# %%
sns.countplot(x='season',data=df)
plt.show()

# %% [markdown]
# data contains equal number of data points of all seasons

# %%
fig,axes = plt.subplots(1,2,figsize=(15,5))
sns.countplot(x='holiday',data=df,ax=axes[0])
sns.countplot(x='workingday',data=df,ax=axes[1])
plt.show()

# %%
df['holiday'].value_counts()
# Out:
# holiday
# 0    10575
# 1      311
# Name: count, dtype: int64

# %%
df['workingday'].value_counts()
# Out:
# workingday
# 1    7412
# 0    3474
# Name: count, dtype: int64

# %%
sns.countplot(x='weather',data=df)
plt.show()

# %% [markdown]
# Mostly good whether is experienced

# %%
fig,axes = plt.subplots(1,3,figsize=(15,5))
sns.histplot(x='temp',data=df,kde=True,ax=axes[0])
sns.histplot(x='atemp',data=df,kde=True,ax=axes[1])
sns.histplot(x='humidity',data=df,kde=True,ax=axes[2])
plt.show()

# %% [markdown]
# most people feel like the temperature is 30 deg maybe becuase of high humidity

# %%
sns.histplot(x='windspeed',data=df,kde=True,bins=10)
plt.show()

# %% [markdown]
# windspeed is usually 0. but more common windspeed is 10-20. however, there is no windspeed recorded between 0-10.

# %%
fig,axes = plt.subplots(1,3,figsize=(15,5))
sns.histplot(x='casual',data=df,kde=True,ax=axes[0])
sns.histplot(x='registered',data=df,kde=True,ax=axes[1])
sns.histplot(x='count',data=df,kde=True,ax=axes[2])
plt.show()

# %%
fig,axes = plt.subplots(1,3,figsize=(15,5))
sns.boxplot(x='count',data=df,ax=axes[0])
sns.boxplot(x='casual',data=df,ax=axes[1])
sns.boxplot(x='registered',data=df,ax=axes[2])
plt.show()

# %% [markdown]
# There seems to be a lot of outliers in the count of cycles recorded. There seems to be few days where there was very unusually very high demand for cycles. We need to find out why that happened

# %%
df
# Out:
#                   datetime season holiday workingday weather   temp   atemp  \
# 0      2011-01-01 00:00:00      1       0          0       1   9.84  14.395
# 1      2011-01-01 01:00:00      1       0          0       1   9.02  13.635
# 2      2011-01-01 02:00:00      1       0          0       1   9.02  13.635
# 3      2011-01-01 03:00:00      1       0          0       1   9.84  14.395
# 4      2011-01-01 04:00:00      1       0          0       1   9.84  14.395
# ...                    ...    ...     ...        ...     ...    ...     ...
# 10881  2012-12-19 19:00:00      4       0          1       1  15.58  19.695
# 10882  2012-12-19 20:00:00      4       0          1       1  14.76  17.425
# 10883  2012-12-19 21:00:00      4       0          1       1  13.94  15.910
# 10884  2012-12-19 22:00:00      4       0          1       1  13.94  17.425
# 10885  2012-12-19 23:00:00      4       0          1       1  13.12  16.665
#
#        humidity  windspeed  casual  registered  count
# ...

# %% [markdown]
# The data contains large number of ouliers.
# We have to decide if the outliers need to be eliminated.
# Maybe the outliers are because of cycle marathon conducted on particular days, or any other events that needed cycles.

# %%
low_count = df[df['count']<100]
low_count
# Out:
#                   datetime season holiday workingday weather   temp   atemp  \
# 0      2011-01-01 00:00:00      1       0          0       1   9.84  14.395
# 1      2011-01-01 01:00:00      1       0          0       1   9.02  13.635
# 2      2011-01-01 02:00:00      1       0          0       1   9.02  13.635
# 3      2011-01-01 03:00:00      1       0          0       1   9.84  14.395
# 4      2011-01-01 04:00:00      1       0          0       1   9.84  14.395
# ...                    ...    ...     ...        ...     ...    ...     ...
# 10864  2012-12-19 02:00:00      4       0          1       1  11.48  15.150
# 10865  2012-12-19 03:00:00      4       0          1       1  10.66  13.635
# 10866  2012-12-19 04:00:00      4       0          1       1   9.84  12.120
# 10867  2012-12-19 05:00:00      4       0          1       1  10.66  14.395
# 10885  2012-12-19 23:00:00      4       0          1       1  13.12  16.665
#
#        humidity  windspeed  casual  registered  count
# ...

# %%
low_count['weather'].value_counts()
# Out:
# weather
# 1    2637
# 2    1159
# 3     516
# Name: count, dtype: int64

# %%
low_count['season'].value_counts()
# Out:
# season
# 1    1578
# 2     961
# 4     953
# 3     820
# Name: count, dtype: int64

# %% [markdown]
# The weather does not seems to be the main issue here. Even when the weather is good there has been considerable amount of low cycle demand. Maybe there can be issue in quality of cycles, customer support, other operational challenges.

# %%
sns.barplot(x='season',y='count',data=df)
plt.show()

# %% [markdown]
# it seems most usage of cyclels come from season 3 (fall) followed by 2 (summer) and 4 (winter). season 1 (spring) has the least usage of cycles.

# %%
# Generate the QQ plot
from scipy.stats import probplot

data = df['count']

fig, ax = plt.subplots(figsize=(8, 6))

probplot(data, dist="norm", plot=ax)
ax.set_title('QQ Plot df')
ax.set_xlabel("Theoretical Quantiles")
ax.set_ylabel("Sample Quantiles")

# Show plot
plt.show()

# %%
# Perform Shapiro-Wilk test
from scipy.stats import shapiro

stat, p = shapiro(data)

# Display results
print(f"Shapiro-Wilk Test Statistic: {stat}")
print(f"P-Value: {p}")

# Interpretation
alpha = 0.05
if p > alpha:
    print("The data appears to be normally distributed (fail to reject H0).")
else:
    print("The data does not appear to be normally distributed (reject H0).")
# Out:
# Shapiro-Wilk Test Statistic: 0.8783658962690556
# P-Value: 5.369837893115507e-68
# The data does not appear to be normally distributed (reject H0).
# /usr/local/lib/python3.10/dist-packages/scipy/stats/_axis_nan_policy.py:531: UserWarning: scipy.stats.shapiro: For N > 5000, computed p-value may not be accurate. Current N is 10886.
#   res = hypotest_fun_out(*samples, **kwds)

# %%
from scipy.stats import levene

s1 = df[df['season'] == 1]['count']
s2 = df[df['season'] == 2]['count']
s3 = df[df['season'] == 3]['count']
s4 = df[df['season'] == 4]['count']

stat, p = levene(s1, s2, s3, s4, center='median')

print(f"Levene's Test Statistic: {stat}")
print(f"P-Value: {p}")

if p > 0.05:
    print("The variances are equal (fail to reject H0).")
else:
    print("The variances are not equal (reject H0).")
# Out:
# Levene's Test Statistic: 187.7706624026276
# P-Value: 1.0147116860043298e-118
# The variances are not equal (reject H0).

# %%
# Perform one-way ANOVA

# Null: Seaon do not have an effect on cycle count (s1 = s2 = s3 = s4)
#alternate: atleast one season do have an effect (s1 != s2 != s3 != s4)
# significance level = 5%

from scipy.stats import f_oneway

s1 = df[df['season'] == 1]['count']
s2 = df[df['season'] == 2]['count']
s3 = df[df['season'] == 3]['count']
s4 = df[df['season'] == 4]['count']

f_stat, p_value = f_oneway(s1, s2, s3, s4)

print(f"F-statistic: {f_stat:.2f}")
print(f"P-value: {p_value}")
# Out:
# F-statistic: 236.95
# P-value: 6.164843386499654e-149

# %% [markdown]
# P value being close to zero. So season has a strong correlation with count.

# %%
# Perform t-test to find if the season having greater count than the other

# Null: Seaon 1 and 2 have same demand for cycle (s2 = s1)
#alternate: season 2 has more demand than that of season 1 (s2 > s1)
# significance level = 5%

from scipy.stats import ttest_ind

t_stat, p_value = ttest_ind(s2, s1, alternative= 'greater')

print(f"T-statistic: {t_stat:.2f}")
print(f"P-value: {p_value}")
# Out:
# T-statistic: 22.42
# P-value: 8.289293670200048e-107

# %% [markdown]
# season 2 has more demand than that of season 1

# %%
# Null: Seaon 2 and 2 have same demand for cycle (s3 = s2)
#alternate: season 3 has more demand than that of season 2 (s3 > s2)
# significance level = 5%

from scipy.stats import ttest_ind

t_stat, p_value = ttest_ind(s3, s2, alternative= 'greater')

print(f"T-statistic: {t_stat:.2f}")
print(f"P-value: {p_value}")

if p_value < 0.05:
 print("reject null hypothesis")
else:
 print("fail to reject null hypothesis")
# Out:
# T-statistic: 3.64
# P-value: 0.00013715780586249322
# reject null hypothesis

# %% [markdown]
#  season 3 has more demand than that of season 2

# %%
# Null: Seaon 3 and 4 have same demand for cycle (s3 = s4)
#alternate: season 3 has more demand than that of season 4 (s3 > s4)
# significance level = 5%

from scipy.stats import ttest_ind

t_stat, p_value = ttest_ind(s3, s4, alternative= 'greater')

print(f"T-statistic: {t_stat:.2f}")
print(f"P-value: {p_value}")

if p_value < 0.05:
 print("reject null hypothesis")
else:
 print("fail to reject null hypothesis")
# Out:
# T-statistic: 6.98
# P-value: 1.6471798336237476e-12
# reject null hypothesis

# %% [markdown]
#  season 3 has more demand than that of season 4

# %%
# Null: Seaon 2 and 4 have same demand for cycle (s2 = s4)
#alternate: season 4 has more demand than that of season 2 (s2 > s4)
# significance level = 5%

from scipy.stats import ttest_ind

t_stat, p_value = ttest_ind(s2, s4, alternative= 'greater')

print(f"T-statistic: {t_stat:.2f}")
print(f"P-value: {p_value}")

if p_value < 0.05:
 print("reject null hypothesis")
else:
 print("fail to reject null hypothesis")
# Out:
# T-statistic: 3.25
# P-value: 0.0005789840847065855
# reject null hypothesis

# %% [markdown]
#  season 2 has more demand than that of season 4

# %%
sns.barplot(x='holiday',data=df,y='count')
plt.show()

# %% [markdown]
# there seems to be no effect of holiday on cycle demand.
# Let's check with performing t-test

# %%
holiday_count = df[df['holiday'] == 1]['count']
non_holiday_count = df[df['holiday'] == 0]['count']

stat, p = levene(holiday_count, non_holiday_count, center='median')

print(f"Levene's Test Statistic: {stat}")
print(f"P-Value: {p}")

if p > 0.05:
    print("The variances are equal (fail to reject H0).")
else:
    print("The variances are not equal (reject H0).")
# Out:
# Levene's Test Statistic: 1.222306875221986e-06
# P-Value: 0.9991178954732041
# The variances are equal (fail to reject H0).

# %%
#Perform t-test to determine holiday as any effect on cycle count

# Null: holiday does not have any effect on cycle count
#alternate: count on holidays more than that on non-holidays
# significance level = 5%

holiday_count = df[df['holiday'] == 1]['count']
non_holiday_count = df[df['holiday'] == 0]['count']

t_stat, p_value = ttest_ind(holiday_count, non_holiday_count)

print(f"T-statistic: {t_stat:.2f}")
print(f"P-value: {p_value}")

if p_value < 0.05:
 print("reject null hypothesis")
else:
 print("fail to reject null hypothesis")
# Out:
# T-statistic: -0.56
# P-value: 0.5736923883271103
# fail to reject null hypothesis

# %%
sns.barplot(x='workingday',data=df,y='count')
plt.show()

# %%
working_count = df[df['workingday'] == 1]['count']
non_working_count = df[df['workingday'] == 0]['count']
stat, p = levene(working_count, non_working_count, center='median')

print(f"Levene's Test Statistic: {stat}")
print(f"P-Value: {p}")

if p > 0.05:
    print("The variances are equal (fail to reject H0).")
else:
    print("The variances are not equal (reject H0).")
# Out:
# Levene's Test Statistic: 0.004972848886504472
# P-Value: 0.9437823280916695
# The variances are equal (fail to reject H0).

# %%
# Perform t-test to datermine wheather working day has any effect on cycle count

# Null: working day and non-working day have same demand for cycle
#alternate: working day has more demand than that of non-working day
# significance level = 5%

from scipy.stats import ttest_ind

working_count = df[df['workingday'] == 1]['count']
non_working_count = df[df['workingday'] == 0]['count']

t_stat, p_value = ttest_ind(working_count, non_working_count, alternative= 'greater')

print(f"T-statistic: {t_stat:.2f}")
print(f"P-value: {p_value}")

if p_value < 0.05:
 print("reject null hypothesis")
else:
 print("fail to reject null hypothesis")
# Out:
# T-statistic: 1.21
# P-value: 0.11322402113180674
# fail to reject null hypothesis

# %%
sns.barplot(x='weather',y='count',data=df)
plt.show()

# %% [markdown]
# cycle demand increases when the weather is good

# %%
df['weather'].value_counts()
# Out:
# weather
# 1    7192
# 2    2834
# 3     859
# 4       1
# Name: count, dtype: int64

# %% [markdown]
# since weather 4 has only one data point, it's ok to not consider for analysis

# %%
w1 = df[df['weather'] == 1]['count']
w2 = df[df['weather'] == 2]['count']
w3 = df[df['weather'] == 3]['count']

stat, p = levene(w1,w2,w3, center='median')

print(f"Levene's Test Statistic: {stat}")
print(f"P-Value: {p}")

if p > 0.05:
    print("The variances are equal (fail to reject H0).")
else:
    print("The variances are not equal (reject H0).")
# Out:
# Levene's Test Statistic: 81.67574924435011
# P-Value: 6.198278710731511e-36
# The variances are not equal (reject H0).

# %%
# perform one-way ANOVA to determine if weather has any effect on count

# Null: weather do not have an effect on cycle count
#alternate: atleast one weather do have an effect
# significance level = 5%

from scipy.stats import f_oneway

w1 = df[df['weather'] == 1]['count']
w2 = df[df['weather'] == 2]['count']
w3 = df[df['weather'] == 3]['count']
#w4 = df[df['weather] == 4]['count']

f_stat, p_value = f_oneway(w1, w2, w3)

print(f"F-statistic: {f_stat:.2f}")
print(f"P-value: {p_value}")

if p_value < 0.05:
 print("reject null hypothesis")
else:
 print("fail to reject null hypothesis")
# Out:
# F-statistic: 98.28
# P-value: 4.976448509904196e-43
# reject null hypothesis

# %% [markdown]
# weather has effect on count

# %%
df.dtypes
# Out:
# datetime       object
# season         object
# holiday        object
# workingday     object
# weather        object
# temp          float64
# atemp         float64
# humidity        int64
# windspeed     float64
# casual          int64
# registered      int64
# count           int64
# dtype: object

# %%
df['humidity'] = df['humidity'].astype(np.float64)

# %%
df.dtypes
# Out:
# datetime       object
# season         object
# holiday        object
# workingday     object
# weather        object
# temp          float64
# atemp         float64
# humidity      float64
# windspeed     float64
# casual          int64
# registered      int64
# count           int64
# dtype: object

# %%
# Specify the target column
target_column = 'count'

# Select numerical columns (float and int)
numerical_columns = df.select_dtypes(include=['float']).columns

# Create subplots
n = len(numerical_columns)
fig, axes = plt.subplots(1, n, figsize=(6 * n, 5), sharey=True)  # Adjust layout based on the number of plots

# Iterate through numerical columns and plot
for i, col in enumerate(numerical_columns):
    sns.scatterplot(data=df, x=col, y=target_column, ax=axes[i])
    axes[i].set_title(f"Scatter: {col} vs {target_column}")
    axes[i].set_xlabel(col)
    axes[i].set_ylabel(target_column)

# Adjust layout
plt.tight_layout()
plt.show()

# %%
# Specify the target column for correlation
target_column = 'count'

# Filter float columns
float_columns = df.select_dtypes(include=['float']).columns

# Calculate correlations
pearson_corr = df[float_columns].corrwith(df[target_column], method='pearson')
spearman_corr = df[float_columns].corrwith(df[target_column], method='spearman')

# Combine results
correlation_results = pd.DataFrame({
    'Pearson': pearson_corr,
    'Spearman': spearman_corr
})
correlation_results
# Out:
#             Pearson  Spearman
# temp       0.394454  0.407989
# atemp      0.389784  0.406562
# humidity  -0.317371 -0.354049
# windspeed  0.101369  0.135777

# %% [markdown]
# looking at the visuals and correlation values, it can be concluded that temperature and humidity does not have an effect on cycle demand

# %%
chi_table = pd.crosstab(df['season'],df[df['weather'] != 4]['weather'])
chi_table
# Out:
# weather     1    2    3
# season
# 1        1759  715  211
# 2        1801  708  224
# 3        1930  604  199
# 4        1702  807  225

# %%
from scipy.stats import chi2_contingency

chi2, p, dof, expected = chi2_contingency(chi_table)
print("Chi-Square Statistic:", chi2)
print("P-Value:", p)
print("Degrees of Freedom:", dof)
print("Expected Frequencies:\n", expected)
# Out:
# Chi-Square Statistic: 46.10145731073249
# P-Value: 2.8260014509929343e-08
# Degrees of Freedom: 6
# Expected Frequencies:
#  [[1774.04869086  699.06201194  211.8892972 ]
#  [1805.76352779  711.55920992  215.67726229]
#  [1805.76352779  711.55920992  215.67726229]
#  [1806.42425356  711.81956821  215.75617823]]

# %% [markdown]
# weather and season are highly correlated

# %% [markdown]
# The data is not normally distributed.
# It is heavily skewed towards right.
# The tests conducted should be considered carefully.
#
# The unsually high demand for cycle on some days can be removed to get more appropriate data.

# %% [markdown]
# Weather and season are the main features on which the cycle demand is associated.
# As said before, even on good weather there seems to be less cycle count.
# Maybe it can be because of low maintanence of cycles, customer support and other issues.
# On harsh weather conditions, ther has been less demand.
# Maybe the company can introduce new features like shades in built for rain protection, more robust cycles that can function in rainy days.
