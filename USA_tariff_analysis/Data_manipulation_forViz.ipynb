# %% [markdown]
# <a href="https://colab.research.google.com/github/vignesh12c/DataViz_analytics_portfolio/blob/main/USA_tariff_analysis/Data_manipulation_forViz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import os

# Load data
customs = pd.read_csv("/content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/CustomsValue_2020_2025.csv")
duties = pd.read_csv("/content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/CalcDuties_2020_2025.csv")
cif = pd.read_csv("/content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/cif_2020_2025.csv")
firstunit = pd.read_csv("/content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/import_firstunit_2020_2025.csv")
secunit = pd.read_csv("/content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/import_secunit_2020_2025.csv")


# Output folder and log file
os.makedirs("/content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out", exist_ok=True)
log_path = "/content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/processed_countries.txt"

# Track processed countries
if os.path.exists(log_path):
    with open(log_path, "r") as f:
        processed = set(f.read().splitlines())
else:
    processed = set()

# Month columns
months = ['January', 'February', 'March', 'April', 'May', 'June',
          'July', 'August', 'September', 'October', 'November', 'December']

# Melt helper
def melt_df(df, value_name):
    return df.melt(
        id_vars=[col for col in df.columns if col not in months],
        value_vars=months,
        var_name='Month',
        value_name=value_name
    )

# Join keys
join_keys = ['HTS Number', 'Country', 'Year', 'Month', 'Program', 'District', 'RPC Description']

# Process one country at a time
all_countries = customs['Country'].dropna().unique()

for country in all_countries:
    if country in processed:
        print(f"✅ Skipping already processed: {country}")
        continue

    try:
        print(f"🔄 Processing {country}...")

        cust_chunk = melt_df(customs[customs['Country'] == country], 'CustomsValue')
        duty_chunk = melt_df(duties[duties['Country'] == country], 'CalcDuties')
        cif_chunk = melt_df(cif[cif['Country'] == country], 'CIF')
        first_chunk = melt_df(firstunit[firstunit['Country'] == country], 'FirstUnit')
        second_chunk = melt_df(secunit[secunit['Country'] == country], 'SecondUnit')

        merged = cust_chunk.merge(duty_chunk, on=join_keys, how='left')
        merged = merged.merge(cif_chunk, on=join_keys, how='left')
        merged = merged.merge(first_chunk, on=join_keys, how='left')
        merged = merged.merge(second_chunk, on=join_keys, how='left')

        # Fill missing values
        merged.fillna(0, inplace=True)

        # Add quarter
        merged['Quarter'] = merged['Month'].map({
            'January': 'Q1', 'February': 'Q1', 'March': 'Q1',
            'April': 'Q2', 'May': 'Q2', 'June': 'Q2',
            'July': 'Q3', 'August': 'Q3', 'September': 'Q3',
            'October': 'Q4', 'November': 'Q4', 'December': 'Q4'
        })

        # Save result
        output_path = f"/content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/{country.replace('/', '_')}.csv"
        merged.to_csv(output_path, index=False)

        # Log progress
        with open(log_path, "a") as f:
            f.write(country + "\n")

        print(f"✅ Saved: {output_path}")

    except Exception as e:
        print(f"❌ Error processing {country}: {e}")
# Out:
# 🔄 Processing Afghanistan...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Afghanistan.csv
# 🔄 Processing Antigua and Barbuda...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Antigua and Barbuda.csv
# 🔄 Processing Argentina...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Argentina.csv
# 🔄 Processing Australia...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Australia.csv
# 🔄 Processing Austria...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Austria.csv
# 🔄 Processing Bahamas...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Bahamas.csv
# 🔄 Processing Bahrain...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Bahrain.csv
# 🔄 Processing Barbados...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Barbados.csv
# 🔄 Processing Belarus...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Belarus.csv
# 🔄 Processing Belgium...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Belgium.csv
# 🔄 Processing Belize...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Belize.csv
# 🔄 Processing Benin...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Benin.csv
# 🔄 Processing Bermuda...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Bermuda.csv
# 🔄 Processing Bolivia...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Bolivia.csv
# 🔄 Processing Bosnia and Herzegovina...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Bosnia and Herzegovina.csv
# 🔄 Processing Brazil...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Brazil.csv
# 🔄 Processing Bulgaria...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Bulgaria.csv
# 🔄 Processing Cambodia...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Cambodia.csv
# 🔄 Processing Canada...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Canada.csv
# 🔄 Processing Chile...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Chile.csv
# 🔄 Processing China...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/China.csv
# 🔄 Processing Christmas Island...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Christmas Island.csv
# 🔄 Processing Colombia...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Colombia.csv
# 🔄 Processing Cook Islands...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Cook Islands.csv
# 🔄 Processing Costa Rica...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Costa Rica.csv
# 🔄 Processing Croatia...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Croatia.csv
# 🔄 Processing Curaçao...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Curaçao.csv
# 🔄 Processing Cyprus...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Cyprus.csv
# 🔄 Processing Czechia (Czech Republic)...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Czechia (Czech Republic).csv
# 🔄 Processing Democratic Republic of the Congo...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Democratic Republic of the Congo.csv
# 🔄 Processing Denmark...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Denmark.csv
# 🔄 Processing Dominican Republic...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Dominican Republic.csv
# 🔄 Processing Ecuador...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Ecuador.csv
# 🔄 Processing Egypt...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Egypt.csv
# 🔄 Processing El Salvador...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/El Salvador.csv
# 🔄 Processing Estonia...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Estonia.csv
# 🔄 Processing Finland...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Finland.csv
# 🔄 Processing France...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/France.csv
# 🔄 Processing Germany...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Germany.csv
# 🔄 Processing Ghana...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Ghana.csv
# 🔄 Processing Greece...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Greece.csv
# 🔄 Processing Guatemala...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Guatemala.csv
# 🔄 Processing Guyana...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Guyana.csv
# 🔄 Processing Haiti...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Haiti.csv
# 🔄 Processing Hong Kong...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Hong Kong.csv
# 🔄 Processing Hungary...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Hungary.csv
# 🔄 Processing Iceland...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Iceland.csv
# 🔄 Processing India...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/India.csv
# 🔄 Processing Indonesia...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Indonesia.csv
# 🔄 Processing Ireland...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Ireland.csv
# 🔄 Processing Israel...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Israel.csv
# 🔄 Processing Italy...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Italy.csv
# 🔄 Processing Japan...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Japan.csv
# 🔄 Processing Jordan...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Jordan.csv
# 🔄 Processing Kazakhstan...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Kazakhstan.csv
# 🔄 Processing Kenya...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Kenya.csv
# 🔄 Processing Kuwait...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Kuwait.csv
# 🔄 Processing Latvia...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Latvia.csv
# 🔄 Processing Lithuania...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Lithuania.csv
# 🔄 Processing Luxembourg...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Luxembourg.csv
# 🔄 Processing Madagascar...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Madagascar.csv
# 🔄 Processing Malaysia...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Malaysia.csv
# 🔄 Processing Mali...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Mali.csv
# 🔄 Processing Mauritius...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Mauritius.csv
# 🔄 Processing Mexico...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Mexico.csv
# 🔄 Processing Montenegro...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Montenegro.csv
# 🔄 Processing Netherlands...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Netherlands.csv
# 🔄 Processing New Zealand...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/New Zealand.csv
# 🔄 Processing Nicaragua...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Nicaragua.csv
# 🔄 Processing North Macedonia...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/North Macedonia.csv
# 🔄 Processing Norway...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Norway.csv
# 🔄 Processing Panama...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Panama.csv
# 🔄 Processing Peru...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Peru.csv
# 🔄 Processing Philippines...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Philippines.csv
# 🔄 Processing Poland...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Poland.csv
# 🔄 Processing Portugal...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Portugal.csv
# 🔄 Processing Qatar...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Qatar.csv
# 🔄 Processing Republic of the Congo...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Republic of the Congo.csv
# 🔄 Processing Romania...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Romania.csv
# 🔄 Processing Russia...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Russia.csv
# 🔄 Processing Saint Kitts and Nevis...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Saint Kitts and Nevis.csv
# 🔄 Processing Saudi Arabia...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Saudi Arabia.csv
# 🔄 Processing Senegal...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Senegal.csv
# 🔄 Processing Serbia...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Serbia.csv
# 🔄 Processing Seychelles...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Seychelles.csv
# 🔄 Processing Sierra Leone...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Sierra Leone.csv
# 🔄 Processing Sint Maarten...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Sint Maarten.csv
# 🔄 Processing Slovakia...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Slovakia.csv
# 🔄 Processing Slovenia...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Slovenia.csv
# 🔄 Processing Solomon Islands...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Solomon Islands.csv
# 🔄 Processing South Africa...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/South Africa.csv
# 🔄 Processing South Korea...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/South Korea.csv
# 🔄 Processing Spain...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Spain.csv
# 🔄 Processing Sudan...
# /tmp/ipython-input-1-541758100.py:62: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   merged.fillna(0, inplace=True)
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Sudan.csv
# 🔄 Processing Suriname...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Suriname.csv
# 🔄 Processing Sweden...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Sweden.csv
# 🔄 Processing Switzerland...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Switzerland.csv
# 🔄 Processing Taiwan...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Taiwan.csv
# 🔄 Processing Thailand...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Thailand.csv
# 🔄 Processing Togo...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Togo.csv
# 🔄 Processing Tokelau...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Tokelau.csv
# 🔄 Processing Turkey...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Turkey.csv
# 🔄 Processing Uganda...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Uganda.csv
# 🔄 Processing Ukraine...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Ukraine.csv
# 🔄 Processing United Arab Emirates...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/United Arab Emirates.csv
# 🔄 Processing United Kingdom...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/United Kingdom.csv
# 🔄 Processing Uruguay...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Uruguay.csv
# 🔄 Processing Uzbekistan...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Uzbekistan.csv
# 🔄 Processing Venezuela...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Venezuela.csv
# 🔄 Processing Vietnam...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Vietnam.csv
# 🔄 Processing Cameroon...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Cameroon.csv
# 🔄 Processing Honduras...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Honduras.csv
# 🔄 Processing Namibia...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Namibia.csv
# 🔄 Processing Armenia...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Armenia.csv
# 🔄 Processing Bangladesh...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Bangladesh.csv
# 🔄 Processing Brunei...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Brunei.csv
# 🔄 Processing Cabo Verde...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Cabo Verde.csv
# 🔄 Processing Côte d`Ivoire...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Côte d`Ivoire.csv
# 🔄 Processing Djibouti...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Djibouti.csv
# 🔄 Processing Falkland Islands...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Falkland Islands.csv
# 🔄 Processing Faroe Islands...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Faroe Islands.csv
# 🔄 Processing Fiji...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Fiji.csv
# 🔄 Processing French Polynesia...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/French Polynesia.csv
# 🔄 Processing Gambia...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Gambia.csv
# 🔄 Processing Gibraltar...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Gibraltar.csv
# 🔄 Processing Greenland...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Greenland.csv
# 🔄 Processing Grenada...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Grenada.csv
# 🔄 Processing Guinea...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Guinea.csv
# 🔄 Processing Jamaica...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Jamaica.csv
# 🔄 Processing Kiribati...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Kiribati.csv
# 🔄 Processing Maldives...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Maldives.csv
# 🔄 Processing Malta...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Malta.csv
# 🔄 Processing Marshall Islands...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Marshall Islands.csv
# 🔄 Processing Mauritania...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Mauritania.csv
# 🔄 Processing Micronesia...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Micronesia.csv
# 🔄 Processing Monaco...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Monaco.csv
# 🔄 Processing Morocco...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Morocco.csv
# 🔄 Processing Mozambique...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Mozambique.csv
# 🔄 Processing Myanmar (Burma)...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Myanmar (Burma).csv
# 🔄 Processing New Caledonia...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/New Caledonia.csv
# 🔄 Processing Nigeria...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Nigeria.csv
# 🔄 Processing Oman...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Oman.csv
# 🔄 Processing Pakistan...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Pakistan.csv
# 🔄 Processing Palau...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Palau.csv
# 🔄 Processing Papua New Guinea...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Papua New Guinea.csv
# 🔄 Processing Reunion...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Reunion.csv
# 🔄 Processing Rwanda...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Rwanda.csv
# 🔄 Processing Saint Helena...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Saint Helena.csv
# 🔄 Processing Saint Vincent and the Grenadines...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Saint Vincent and the Grenadines.csv
# 🔄 Processing Samoa...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Samoa.csv
# 🔄 Processing Singapore...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Singapore.csv
# 🔄 Processing Sri Lanka...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Sri Lanka.csv
# 🔄 Processing Tanzania...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Tanzania.csv
# 🔄 Processing Tonga...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Tonga.csv
# 🔄 Processing Trinidad and Tobago...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Trinidad and Tobago.csv
# 🔄 Processing Tunisia...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Tunisia.csv
# 🔄 Processing Turks and Caicos Islands...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Turks and Caicos Islands.csv
# 🔄 Processing Vanuatu...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Vanuatu.csv
# 🔄 Processing Yemen...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Yemen.csv
# 🔄 Processing Zambia...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Zambia.csv
# 🔄 Processing Albania...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Albania.csv
# 🔄 Processing Georgia...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Georgia.csv
# 🔄 Processing Kyrgyzstan...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Kyrgyzstan.csv
# 🔄 Processing Lebanon...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Lebanon.csv
# 🔄 Processing Moldova...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Moldova.csv
# 🔄 Processing Nepal...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Nepal.csv
# 🔄 Processing Syria...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Syria.csv
# 🔄 Processing West Bank...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/West Bank.csv
# 🔄 Processing Paraguay...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Paraguay.csv
# 🔄 Processing Zimbabwe...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Zimbabwe.csv
# 🔄 Processing Burkina Faso...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Burkina Faso.csv
# 🔄 Processing Ethiopia...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Ethiopia.csv
# 🔄 Processing Saint Lucia...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Saint Lucia.csv
# 🔄 Processing Dominica...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Dominica.csv
# 🔄 Processing Iran...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Iran.csv
# 🔄 Processing Iraq...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Iraq.csv
# 🔄 Processing Kosovo...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Kosovo.csv
# 🔄 Processing Liberia...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Liberia.csv
# 🔄 Processing Malawi...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Malawi.csv
# 🔄 Processing Mayotte...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Mayotte.csv
# 🔄 Processing Turkmenistan...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Turkmenistan.csv
# 🔄 Processing Algeria...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Algeria.csv
# 🔄 Processing Azerbaijan...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Azerbaijan.csv
# 🔄 Processing Guinea-Bissau...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Guinea-Bissau.csv
# 🔄 Processing Somalia...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Somalia.csv
# 🔄 Processing Tajikistan...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Tajikistan.csv
# 🔄 Processing Angola...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Angola.csv
# 🔄 Processing Burundi...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Burundi.csv
# 🔄 Processing Cayman Islands...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Cayman Islands.csv
# 🔄 Processing Comoros...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Comoros.csv
# 🔄 Processing Laos...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Laos.csv
# 🔄 Processing Lesotho...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Lesotho.csv
# 🔄 Processing Timor-Leste...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Timor-Leste.csv
# 🔄 Processing Central African Republic...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Central African Republic.csv
# 🔄 Processing Mongolia...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Mongolia.csv
# 🔄 Processing Norfolk Island...
# /tmp/ipython-input-1-541758100.py:62: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   merged.fillna(0, inplace=True)
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Norfolk Island.csv
# 🔄 Processing San Marino...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/San Marino.csv
# 🔄 Processing Chad...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Chad.csv
# 🔄 Processing Macau...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Macau.csv
# 🔄 Processing Aruba...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Aruba.csv
# 🔄 Processing Botswana...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Botswana.csv
# 🔄 Processing Gaza Strip...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Gaza Strip.csv
# 🔄 Processing Eswatini (Swaziland)...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Eswatini (Swaziland).csv
# 🔄 Processing São Tomé and Príncipe...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/São Tomé and Príncipe.csv
# 🔄 Processing Andorra...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Andorra.csv
# 🔄 Processing British Virgin Islands...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/British Virgin Islands.csv
# 🔄 Processing Gabon...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Gabon.csv
# 🔄 Processing Eritrea...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Eritrea.csv
# 🔄 Processing Bhutan...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Bhutan.csv
# 🔄 Processing Martinique...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Martinique.csv
# 🔄 Processing Anguilla...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Anguilla.csv
# 🔄 Processing Guadeloupe...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Guadeloupe.csv
# 🔄 Processing Montserrat ...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Montserrat .csv
# 🔄 Processing Libya...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Libya.csv
# 🔄 Processing Liechtenstein...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Liechtenstein.csv
# 🔄 Processing Equatorial Guinea...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Equatorial Guinea.csv
# 🔄 Processing Niger...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Niger.csv
# 🔄 Processing French Guiana...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/French Guiana.csv
# 🔄 Processing Cocos (Keeling) Islands...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Cocos (Keeling) Islands.csv
# 🔄 Processing Western Sahara...
# /tmp/ipython-input-1-541758100.py:62: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   merged.fillna(0, inplace=True)
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Western Sahara.csv
# 🔄 Processing British Indian Ocean Territory...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/British Indian Ocean Territory.csv
# 🔄 Processing French Southern and Antarctic Lands...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/French Southern and Antarctic Lands.csv
# 🔄 Processing Nauru...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Nauru.csv
# 🔄 Processing Vatican City...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Vatican City.csv
# 🔄 Processing Niue...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Niue.csv
# 🔄 Processing Tuvalu...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Tuvalu.csv
# 🔄 Processing Cuba...
# /tmp/ipython-input-1-541758100.py:62: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   merged.fillna(0, inplace=True)
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Cuba.csv
# 🔄 Processing Saint Pierre and Miquelon...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Saint Pierre and Miquelon.csv
# 🔄 Processing Wallis and Futuna...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Wallis and Futuna.csv
# 🔄 Processing Heard and McDonald Islands...
# /tmp/ipython-input-1-541758100.py:62: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   merged.fillna(0, inplace=True)
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Heard and McDonald Islands.csv
# 🔄 Processing Pitcairn Islands...
# /tmp/ipython-input-1-541758100.py:62: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   merged.fillna(0, inplace=True)
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Pitcairn Islands.csv
# 🔄 Processing South Sudan...
# /tmp/ipython-input-1-541758100.py:62: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   merged.fillna(0, inplace=True)
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/South Sudan.csv
# 🔄 Processing Svalbard and Jan Mayen...
# ✅ Saved: /content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/Svalbard and Jan Mayen.csv
# /tmp/ipython-input-1-541758100.py:62: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   merged.fillna(0, inplace=True)

# %%
import glob

all_files = glob.glob("/content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/*.csv")
final_df = pd.concat((pd.read_csv(f) for f in all_files), ignore_index=True)
final_df.to_csv("/content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/merged_imports_long_FINAL.csv", index=False)

# %%
mer_file = pd.read_csv("/content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/out/merged_imports_long_FINAL.csv")
mer_file.head()

# %%
import pandas as pd

# === Load CSVs ===
cif = pd.read_csv("/content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/cif_2020_2025.csv")
customs = pd.read_csv("/content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/CustomsValue_2020_2025.csv")
duties = pd.read_csv("/content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/CalcDuties_2020_2025.csv")

# === Function to extract unique values ===
def extract_uniques(df, name):
    result = {
        'Country': set(df['Country'].dropna().unique()),
        'RPC': set(df['RPC Description'].dropna().unique()),
        'District': set(df['District'].dropna().unique()),
        'Program': set(df['Program'].dropna().unique())
    }
    print(f"\n✅ {name} - Unique counts:")
    for key in result:
        print(f"  {key}: {len(result[key])}")
    return result

# === Extract unique values from all 3 ===
cif_uniques = extract_uniques(cif, "CIF")
customs_uniques = extract_uniques(customs, "CustomsValue")
duties_uniques = extract_uniques(duties, "CalcDuties")

# === Compare mismatches ===
def compare_sets(set1, set2, label1, label2, field):
    diff1 = set1 - set2
    diff2 = set2 - set1
    print(f"\n🔍 Comparing {field} between {label1} and {label2}:")
    if diff1:
        print(f"  → In {label1} but not in {label2}: {sorted(list(diff1))[:5]}... ({len(diff1)} total)")
    if diff2:
        print(f"  → In {label2} but not in {label1}: {sorted(list(diff2))[:5]}... ({len(diff2)} total)")
    if not diff1 and not diff2:
        print("  ✅ Perfect match!")

# === Run comparisons for all fields across all files ===
fields = ['Country', 'RPC', 'District', 'Program']
labels = [('CIF', cif_uniques), ('CustomsValue', customs_uniques), ('CalcDuties', duties_uniques)]

for i in range(len(labels)):
    for j in range(i + 1, len(labels)):
        label1, data1 = labels[i]
        label2, data2 = labels[j]
        for field in fields:
            compare_sets(data1[field], data2[field], label1, label2, field)
# Out:
# ✅ CIF - Unique counts:
#   Country: 233
#   RPC: 13
#   District: 44
#   Program: 33
#
# ✅ CustomsValue - Unique counts:
#   Country: 233
#   RPC: 13
#   District: 44
#   Program: 33
#
# ✅ CalcDuties - Unique counts:
#   Country: 233
#   RPC: 13
#   District: 44
#   Program: 33
#
# 🔍 Comparing Country between CIF and CustomsValue:
#   ✅ Perfect match!
#
# 🔍 Comparing RPC between CIF and CustomsValue:
#   ✅ Perfect match!
#
# 🔍 Comparing District between CIF and CustomsValue:
#   ✅ Perfect match!
#
# 🔍 Comparing Program between CIF and CustomsValue:
#   ✅ Perfect match!
#
# 🔍 Comparing Country between CIF and CalcDuties:
#   ✅ Perfect match!
#
# 🔍 Comparing RPC between CIF and CalcDuties:
#   ✅ Perfect match!
#
# 🔍 Comparing District between CIF and CalcDuties:
#   ✅ Perfect match!
#
# 🔍 Comparing Program between CIF and CalcDuties:
#   ✅ Perfect match!
#
# 🔍 Comparing Country between CustomsValue and CalcDuties:
#   ✅ Perfect match!
#
# 🔍 Comparing RPC between CustomsValue and CalcDuties:
#   ✅ Perfect match!
#
# 🔍 Comparing District between CustomsValue and CalcDuties:
#   ✅ Perfect match!
#
# 🔍 Comparing Program between CustomsValue and CalcDuties:
#   ✅ Perfect match!

# %%
import pandas as pd

# Load files
cif = pd.read_csv("/content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/cif_2020_2025.csv")
customs = pd.read_csv("/content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/CustomsValue_2020_2025.csv")
duties = pd.read_csv("/content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/CalcDuties_2020_2025.csv")

# Common settings
months = ['January', 'February', 'March', 'April', 'May', 'June',
          'July', 'August', 'September', 'October', 'November', 'December']

# Key columns used to identify unique records (excluding month)
group_keys = ['HTS Number', 'Country', 'Year', 'Month', 'Program', 'District', 'RPC Description']

# Function to unpivot and aggregate
def melt_and_aggregate(df, value_name):
    # Melt from wide to long format
    df_long = df.melt(
        id_vars=[col for col in df.columns if col not in months],
        value_vars=months,
        var_name='Month',
        value_name=value_name
    )

    # Drop rows with all missing values in the value column
    df_long = df_long.dropna(subset=[value_name])

    # Aggregate to handle duplicates
    df_agg = df_long.groupby(group_keys, as_index=False)[value_name].sum()

    print(f"✅ {value_name}: {len(df)} → {len(df_long)} rows after melting, {len(df_agg)} after aggregation")
    return df_agg

# Process each dataset
cif_long = melt_and_aggregate(cif, 'CIF')
customs_long = melt_and_aggregate(customs, 'CustomsValue')
duties_long = melt_and_aggregate(duties, 'CalcDuties')

# Save processed long-format files
cif_long.to_csv("/content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/long_cleaned_cif.csv", index=False)
customs_long.to_csv("/content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/long_cleaned_customsvalue.csv", index=False)
duties_long.to_csv("/content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/long_cleaned_calcduties.csv", index=False)

print("📁 All cleaned and long-format files saved.")
# Out:
# ✅ CIF: 1498622 → 17983464 rows after melting, 10637616 after aggregation
# ✅ CustomsValue: 1445483 → 17345796 rows after melting, 10398096 after aggregation
# ✅ CalcDuties: 1498640 → 17983680 rows after melting, 10637832 after aggregation
# 📁 All cleaned and long-format files saved.

# %%
import pandas as pd

# === Load long-format cleaned CSVs ===
cif = pd.read_csv("/content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/long_cleaned_cif.csv")
customs = pd.read_csv("/content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/long_cleaned_customsvalue.csv")
duties = pd.read_csv("/content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/long_cleaned_calcduties.csv")

# === Define keys for joining ===
join_keys = ['HTS Number', 'Country', 'Year', 'Month', 'Program', 'District', 'RPC Description']

# === Merge using left joins on customs as base ===
merged = customs.merge(duties, on=join_keys, how='left')
merged = merged.merge(cif, on=join_keys, how='left')

# === Fill missing values with 0 ===
merged.fillna(0, inplace=True)


# === Optional: Add Quarter column for trend analysis ===
merged['Quarter'] = merged['Month'].map({
    'January': 'Q1', 'February': 'Q1', 'March': 'Q1',
    'April': 'Q2', 'May': 'Q2', 'June': 'Q2',
    'July': 'Q3', 'August': 'Q3', 'September': 'Q3',
    'October': 'Q4', 'November': 'Q4', 'December': 'Q4'
})

# === Save final merged file ===
merged.to_csv("/content/drive/MyDrive/DatawebUSITC/csv_output/merged_output/final_merged_imports2.csv", index=False)
print("✅ Final merged and enriched file saved as: final_merged_imports2.csv")
# Out:
# ✅ Final merged and enriched file saved as: final_merged_imports2.csv

# %%
len(merged)
# Out:
# 10398096

# %%
merged.head()
# Out:
#    HTS Number      Country  Year     Month                      Program  \
# 0           1  Afghanistan  2020     April  No special programs claimed
# 1           1  Afghanistan  2020    August  No special programs claimed
# 2           1  Afghanistan  2020  December  No special programs claimed
# 3           1  Afghanistan  2020  February  No special programs claimed
# 4           1  Afghanistan  2020   January  No special programs claimed
#
#                 District                   RPC Description  CustomsValue  \
# 0  Houston-Galveston, TX  10 - Free under HS Chapters 1-98           0.0
# 1  Houston-Galveston, TX  10 - Free under HS Chapters 1-98           0.0
# 2  Houston-Galveston, TX  10 - Free under HS Chapters 1-98           0.0
# 3  Houston-Galveston, TX  10 - Free under HS Chapters 1-98           0.0
# 4  Houston-Galveston, TX  10 - Free under HS Chapters 1-98           0.0
#
#    CalcDuties  CIF Quarter
# 0         0.0  0.0      Q2
# 1         0.0  0.0      Q3
# 2         0.0  0.0      Q4
# 3         0.0  0.0      Q1
# 4         0.0  0.0      Q1
